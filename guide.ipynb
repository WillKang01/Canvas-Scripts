# %% [markdown]
# If you cannot see any of the images, you might have to click on the cell and hit Shift + Enter. Or go to the top and run all the cells.

# %% [markdown]
# # Generate a Canvas Access Token

# %% [markdown]
# #### Navigate to settings
#
# ![image.png](attachment:f43966c0-db7a-48e7-8b70-369462b55de5.png)

# %% [markdown]
# #### Click "+ New Access Token"
#
# ![image.png](attachment:f502473c-f388-444f-b50a-30f58f04b0d2.png)

# %% [markdown]
# #### Enter the purpose and give an expiry date (the token cannot be used after the expiry date)
#
# ![image.png](attachment:73840c38-b622-437a-a053-a6718224e1db.png)

# %% [markdown]
# #### Copy the token generated (this is your only chance to copy it).
# ### NOTE: NEVER SHARE THIS TOKEN, ANYONE WITH THIS TOKEN CAN PERFORM ALL ACTIONS THAT YOU CAN ON CANVAS
# ## If you accidently shared your token, make sure you go to Canvas and delete the token.
#
# ![image.png](attachment:abe1a109-21a6-41b6-a3f5-52e2ebc1957e.png)

# %% [markdown]
# #### Paste your token in the code:
#
# ![image.png](attachment:5a3bb4a0-c273-41dd-81dd-402882589603.png)

# %% [markdown]
# # Running the Script

# %% [markdown]
# #### Open an ipykernal
#
# ![image.png](attachment:55804df7-92fb-4e1c-96ff-2231b70652c1.png)

# %% [markdown]
# #### Type in the command:
# ```%run assign_groups.py```
#
# ![image.png](attachment:8ae37af2-4948-47b7-a11c-2c66e39aef9c.png)
#
# ##### Then hit Shift + Enter

# %% [markdown]
# #### Follow the prompts and type in your answers accordingly
#
# ##### Note: When inputting values, hit Enter to submit
#
# ![image.png](attachment:5d21696a-a0eb-4627-a5e5-2587b6c8bbcb.png)
#
# #### Note, your canvas course id can be found in the url when you are inside your course
#
# ![image.png](attachment:d5de3137-3bf6-476b-b9d1-7a0b3c0035c5.png)

# %% [markdown]
# ## Example
# #### Before:
#
# ![image.png](attachment:459928ae-89e9-4e37-9b00-ee9c51f475b6.png)

# %% [markdown]
# #### Running Script:
#
# ![image.png](attachment:5ef59e35-ba6a-4d2c-9a49-41aafda06eb1.png)

# %% [markdown]
# #### After:
#
# ![image.png](attachment:63fcb3e1-fe53-4239-a2cd-afad2bc8c441.png)

# %% [markdown]
# ### Troubleshooting
#
# If you see an error like this one below: Make sure the assignment is only assigned to "Everyone".
#
# ![image.png](attachment:ed07f4b9-43ba-4368-95a2-b651475f8e18.png)
#
# If you see an error like ModuleNotFoundError: No module named 'canvasapi' or ModuleNotFoundError: No module named 'numpy'
# Then you can enter the following commands into your terminal respectively
#
# ![image.png](attachment:fea76902-1ab6-4ff4-98fa-8dca0ca0bc88.png)
#
# ![image.png](attachment:4d1f1694-1ff8-4433-bb3b-6afbfb829ad0.png)
